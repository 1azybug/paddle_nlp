# %%
import json
import os

# %%
def read_by_lines(path):
    result=[]
    with open(path,'r') as infile:
        for line in infile:
            result.append(line.strip())
    return result

def write_by_lines(path,data):
    with open(path,'w') as outfile:
        [outfile.write(d+'\n') for d in data]

def load_dict(dict_path):
    vocab={}
    for line in open(dict_path,'r',encoding='utf-8'):
        value,key=line.strip().split('\t')
        vocab[key]=int(value)
    return vocab

# %%
def data_process(path,mode='trigger',is_predict=False):
    def label_data(data,start,l,_type):
        for i in range(start,start+l):
            suffix='B-' if i==start else "I-"
            data[i]=suffix+str(_type)
        return data
    
    sents=[]
    output=["text_a"] if is_predict else ["text_a\tlabel"]
    with open(path) as f:
        for line in f:
            d_json=json.loads(line.strip())
            _id=d_json["id"]
            text_a=["," if t==' ' or t=='\n' or t=='\t' else t for t in list(d_json['text'].lower())]

            if is_predict:
                sents.append({'text':d_json['text'],"id":_id})
                output.append('\002'.join(text_a))
            else:
                if mode=='trigger':
                    labels=["O"]*len(text_a)
                    for event in d_json.get('event_list',[]):
                        event_type=event['event_type']
                        start=event['trigger_start_index']
                        trigger=event['trigger']
                        labels=label_data(labels,start,len(trigger),event_type)
                    output.append("{}\t{}".format('\002'.join(text_a),'\002'.join(labels)))
                elif mode=='role':
                    for event in d_json.get('event_list',[]):#不存在event_list时不进人该层循环,eg:test.json,训练不会用到test,无伤大雅
                        labels=["O"]*len(text_a)
                        for arg in event['arguments']:
                            role_type=arg['role']
                            argument=arg["argument"]
                            start=arg['argument_start_index']
                            labels=label_data(labels,start,len(argument),role_type)
                        output.append("{}\t{}".format('\002'.join(text_a),'\002'.join(labels)))
    return output

# %%
def schema_process(path,mode='trigger'):
    def label_add(labels,_type):
        if 'B-{}'.format(_type) not in labels:
            labels.extend(["B-{}".format(_type),"I-{}".format(_type)])
        return labels
    
    labels=[]
    for line in read_by_lines(path):
        d_json=json.loads(line)
        if mode=='trigger':
            labels=label_add(labels,d_json['event_type'])
        elif mode=='role':
            for role in d_json['role_list']:
                labels=label_add(labels,role['role'])
    labels.append("O")
    tags=[]
    for ind,label in enumerate(labels):
        tags.append("{}\t{}".format(ind,label))
    return tags

# %%
conf_dir='./data/data158120'
schema_path="{}/event_schema.json".format(conf_dir)
tags_trigger_path="{}/trigger_tag.dict".format(conf_dir)
tags_role_path="{}/role_tag.dict".format(conf_dir)

tags_trigger=schema_process(schema_path,'trigger')
write_by_lines(tags_trigger_path,tags_trigger)

tags_role=schema_process(schema_path,'role')
write_by_lines(tags_role_path,tags_role)


data_dir=conf_dir
trigger_save_dir="{}/trigger".format(data_dir)
role_save_dir="{}/role".format(data_dir)

if not os.path.exists(trigger_save_dir):
    os.makedirs(trigger_save_dir)
if not os.path.exists(role_save_dir):
    os.makedirs(role_save_dir)

# %%
train_tri=data_process("{}/train.json".format(data_dir),"trigger")
write_by_lines("{}/train.tsv".format(trigger_save_dir),train_tri)

dev_tri=data_process("{}/dev.json".format(data_dir),"trigger")
write_by_lines("{}/dev.tsv".format(trigger_save_dir),dev_tri)

test_tri=data_process("{}/test.json".format(data_dir),"trigger")
write_by_lines("{}/test.tsv".format(trigger_save_dir),test_tri)

# %%
train_role=data_process("{}/train.json".format(data_dir),"role")
write_by_lines("{}/train.tsv".format(role_save_dir),train_role)

dev_role=data_process("{}/dev.json".format(data_dir),"role")
write_by_lines("{}/dev.tsv".format(role_save_dir),dev_role)


#训练不会用到
test_role=data_process("{}/test.json".format(data_dir),'role')
write_by_lines("{}/test.tsv".format(role_save_dir),test_role)

# %% [markdown]
# # 构建词典

# %%
def get_vocab():
    train_lines=open('data/data158120/train.json','r',encoding='utf-8').readlines()
    dev_lines=open('data/data158120/dev.json','r',encoding='utf-8').readlines()
    lines=train_lines+dev_lines
    vocab=set()
    for line in lines:
        ll=json.loads(line.strip())
        for c in ll['text']:
            vocab.add(c)
    
    vocab={c:i+2 for i,c in enumerate(list(vocab))}
    vocab['<pad>'],vocab['<unk>']=0,1
    return vocab

# %%
vocab=get_vocab()
vocab_size=len(list(vocab))

# %%
#将一句str转化为ids
def word2id(line,vocab,max_len=145):
    r=[]
    for c in line:
        if c not in vocab:
            r.append(vocab['<unk>'])
        else:
            r.append(vocab[c])
    r=r[:max_len]
    lens=len(r)#记录截断后,未填充时的长度
    r=r+[0]*(max_len-len(r))
    # print("line:",line)
    # print("r:",r,"lens:",lens)
    return r,lens

# %% [markdown]
# # 配置BiLSTM+CRF模型

# %%
import paddle
import paddle.nn as nn

# %%
class LSTM_Model(nn.Layer):
    def __init__(self,vocab_num,emb_size,hidden_size,num_layers,num_labels,dropout):
        super(LSTM_Model,self).__init__()
        self.embedding=nn.Embedding(vocab_num,emb_size)
        self.lstm=nn.LSTM(emb_size,hidden_size,num_layers=num_layers,direction='bidirect',dropout=dropout)
        self.linear=nn.Linear(hidden_size*2,num_labels+2)
        self.dropout=nn.Dropout(dropout)
        self.crf=LinearChainCrf(num_labels)
        self.decoder=ViterbiDecoder(self.crf.transitions)
    
    def forward(self,input_ids,seq_lens=None,target=None):
        token_emb=self.embedding(input_ids)
        sequence_output,_=self.lstm(token_emb)
        outputs=self.linear(sequence_output)
        _,logits=self.decoder(outputs,seq_lens)
        return outputs,logits

# %% [markdown]
# # 模型训练

# %%
num_epoch=10
learning_rate=0.001
base_dir='./data/data158120'
tag_path="{}/trigger_tag.dict".format(base_dir)

data_dir="{}/trigger".format(base_dir)
train_data="{}/train.tsv".format(data_dir)
dev_data="{}/dev.tsv".format(data_dir)
test_data="{}/test.tsv".format(data_dir)

predict_data="{}/test.json".format(base_dir)

checkpoints="{}/trigger/".format(base_dir)
init_ckpt="{}/trigger/best.pdparams".format(base_dir)

weight_decay=0.01
warmup_proportion=0.1
max_seq_len=145
valid_step=500
skip_step=50
batch_size=32
predict_save_path=None
seed=1024

# %%
def convert_example_to_feature(example,label_vocab=None,max_seq_len=145,no_entity_label='O',ignore_label=-1,is_test=False):
    tokens,labels,seq_len=example
    input_ids,seq_lens=word2id(tokens,vocab)
    if is_test:
        return input_ids,seq_lens
    elif label_vocab is not None:
        encoded_label=labels[:seq_lens]
        encoded_label=[label_vocab[x] for x in encoded_label]
        # print("convert:")
        # print(len(encoded_label),max_seq_len,seq_lens)
        encoded_label=encoded_label+[-1]*(max_seq_len-seq_lens)
        # print(len(encoded_label),max_seq_len,seq_lens)
        return input_ids,encoded_label,seq_lens

# %%
class DuEventExtraction(paddle.io.Dataset):
    def __init__(self,data_path,tag_path):
        self.label_vocab=load_dict(tag_path)
        self.word_ids=[]
        self.label_ids=[]
        self.seq_lens=[]
        with open(data_path,'r',encoding='utf-8') as fp:
            next(fp)#不要第一行 ,第一行是output=["text_a"] if is_predict else ["text_a\tlabel"]
            for line in fp.readlines():
                words,labels=line.strip().split('\t')
                words=words.split('\002')
                labels=labels.split('\002')
                self.word_ids.append(words)
                self.label_ids.append(labels)
                self.seq_lens.append(len(words[:145]))
        self.label_num=max(self.label_vocab.values())+1
    
    def __len__(self):
        return len(self.word_ids)
    
    def __getitem__(self,index):
        return self.word_ids[index],self.label_ids[index],self.seq_lens[index]

# %%
def do_train():
    paddle.set_device('gpu')
    no_entity_label="O"
    ignore_label=-1
    label_map=load_dict(tag_path)
    id2label={val:key for key,val in label_map.items()}
    vocab_num,emb_size,hidden_size,num_layers,num_labels,dropout=vocab_size,256,256,2,len(list(id2label)),0.1

    model=LSTM_Model(vocab_num,emb_size,hidden_size,num_layers,num_labels,dropout)
    
    train_ds=DuEventExtraction(train_data,tag_path)
    dev_ds=DuEventExtraction(dev_data,tag_path)
    test_ds=DuEventExtraction(test_data,tag_path)

    trans_func=partial(
        convert_example_to_feature,
        label_vocab=train_ds.label_vocab,
        max_seq_len=max_seq_len,
        no_entity_label=no_entity_label,
        ignore_label=ignore_label,
        is_test=False
    )

    batchify_fn=lambda samples,fn=Tuple(
        Pad(axis=0,pad_val=0),
        Pad(axis=0,pad_val=0),
        Stack()
    ):fn(list(map(trans_func,samples)))

    batch_sampler=paddle.io.DistributedBatchSampler(train_ds,batch_size=batch_size,shuffle=True)

    train_loader=paddle.io.DataLoader(
        dataset=train_ds,
        batch_sampler=batch_sampler,
        collate_fn=batchify_fn
    )

    dev_loader=paddle.io.DataLoader(
        dataset=dev_ds,
        batch_size=batch_size,
        collate_fn=batchify_fn
    )

    test_loader=paddle.io.DataLoader(
        dataset=test_ds,
        batch_size=batch_size,
        collate_fn=batchify_fn
    )

    num_training_steps=len(train_loader)*num_epoch
    decay_params=[p.name for n,p in model.named_parameters() if not any(nd in n for nd in ['bias','norm'])]

    optimizer=paddle.optimizer.AdamW(
        learning_rate=learning_rate,
        parameters=model.parameters(),
        weight_decay=weight_decay,
        apply_decay_param_fun=lambda x : x in decay_params
    )

    metric=ChunkEvaluator(label_list=train_ds.label_vocab.keys(),suffix=False)
    criterion=LinearChainCrfLoss(model.crf)

    step,best_f1=0,0.0
    model.train()
    for epoch in range(num_epoch):
        for idx,(input_ids,labels,seq_lens) in enumerate(train_loader):
            # print("input_ids:",input_ids[:3])
            outputs,logits=model(input_ids,seq_lens,labels)
            # print(labels.shape,outputs.shape)
            loss=criterion(inputs=outputs,lengths=seq_lens,labels=labels)
            loss=paddle.mean(loss)
            loss.backward()
            optimizer.step()
            optimizer.clear_grad()
            loss_item=loss.numpy().item()
            
            if step>0 and step%skip_step==0:
                print(f'train epoch:{epoch} - step:{step} (total:{num_training_steps}) - loss:{loss_item:.6f}')
            
            if step>0 and step%valid_step==0:
                p,r,f1,avg_loss=evaluate(model,criterion,metric,len(label_map),dev_loader)
                print(f'dev step:{step} - loss:{avg_loss:.5f},precision:{p:.5f},recall:{r:.5f},f1:{f1:.5f}current best {best_f1:.5f}')
                if f1>best_f1:
                    best_f1=f1
                    print(f'=======================save best model \nbest performerence {best_f1:.5f}')
                    paddle.save(model.state_dict(),'{}/best.pdparams'.format(checkpoints))
            
            step+=1

    paddle.save(model.state_dict(),"{}/final.pdparams".format(checkpoints))

# %%
@paddle.no_grad()
def evaluate(model,criterion,metric,num_label,data_loader):
    model.eval()
    metric.reset()
    losses=[]
    for input_ids,labels,seq_lens in data_loader:
        outputs,logits=model(input_ids,seq_lens,labels)
        preds=logits
        n_infer,n_label,n_correct=metric.compute(None,seq_lens,preds,labels)
        metric.update(n_infer.numpy(),n_label.numpy(),n_correct.numpy())
    
        loss=paddle.mean(
            criterion(inputs=outputs,lengths=seq_lens,labels=labels)
        )
        losses.append(loss.numpy()[0])
    
    avg_loss=np.mean(losses)
    precision,recall,f1_score=metric.accumulate()

    model.train()
    return precision,recall,f1_score,avg_loss

# %% [markdown]
# # 训练事件识别模型

# %%
import numpy as np

# %%
from paddlenlp.layers import LinearChainCrfLoss,ViterbiDecoder,LinearChainCrf
from functools import partial
from paddlenlp.data import Stack,Tuple,Pad
from paddlenlp.metrics import ChunkEvaluator

# %%
def do_predict():
    step=0
    paddle.set_device('gpu')
    no_entity_label="O"
    ignore_label=-1
    label_map=load_dict(tag_path)
    id2label={val:key for key,val in label_map.items()}
    vocab_num,emb_size,hidden_size,num_layers,num_labels,dropout=vocab_size,256,256,2,len(list(id2label)),0.1
    model=LSTM_Model(vocab_num,emb_size,hidden_size,num_layers,num_labels,dropout)

    if not init_ckpt or not os.path.isfile(init_ckpt):
        raise Exception("init checkpoints {} not exist".format(init_ckpt))
    else:
        state_dict=paddle.load(init_ckpt)
        model.set_dict(state_dict)
        print("Loaded parameters from {}".format(init_ckpt))
    
    sentences=read_by_lines(predict_data)
    sentences=[json.loads(sent) for sent in sentences]
    encoded_inputs_list=[]
    for sent in sentences:
        # print("be",sent['text'])
        # sent=sent['text'].replace('',"\002")#感觉是多余之举,后面convert example to feature 也没有用到\002分词,而且只有少数有空格
        #如果第一个参数是空串,则会间隔插入\002,包含前后
        #两种情况都不对,所以应该把这句话删掉
        # print("ed",sent)
        # print("sent:",sent)
        # print("list(sent)",list(sent))
        sent=sent['text']#这句话漏了会出bug
        input_ids=convert_example_to_feature([list(sent),[],len(sent)],max_seq_len=max_seq_len,is_test=True)#返回input_ids,seq_lens
        # print("input_ids",input_ids[0])
        encoded_inputs_list.append((input_ids))


    batchify_fn=lambda samples,fn=Tuple(
        Pad(axis=0,pad_val=0),
        Stack()
    ):fn(samples)

    batch_encoded_inputs=[encoded_inputs_list[i:i+batch_size] for i in range(0,len(encoded_inputs_list),batch_size)]

    results=[]
    model.eval()
    for batch in batch_encoded_inputs:
        input_ids,seq_lens=batchify_fn(batch)
        # print("input_ids:",input_ids[:10])
        input_ids=paddle.to_tensor(input_ids)
        seq_lens=paddle.to_tensor(seq_lens)
        
        outputs,logits=model(input_ids,seq_lens)
        probs_ids=logits.numpy()
        for p_ids,seq_len in zip(probs_ids.tolist(),seq_lens.numpy().tolist()):
            # label_one=[id2label[pid] for pid in p_ids[1:seq_len-1]]#为什么要[1:seq_len-1]
            label_one=[id2label[pid] for pid in p_ids[:seq_len]]
            # print("p_ids",p_ids)
            # print([id2label[pid] for pid in p_ids])
            results.append({'label':label_one})
            if step>0 and step%skip_step==0:
                print(f' step:{step}')
            step+=1
            if step>=100:#只看前面十个predict这么久干嘛
                break

        if step>=100:#只看前面十个predict这么久干嘛
            break 
    
    sentences=sentences[:len(results)]# 少predict了很多,加这个
    assert len(results) == len(sentences)
    # print(results[:10])
    for sent,ret in zip(sentences,results):
        sent["pred"]=ret
    
    sentences=[json.dumps(sent,ensure_ascii=False) for sent in sentences]

    # print(sentences[:50])
    for sent in sentences[:50]:
        print('='*10)
        print(type(sent))
        print(sent)
        # print(sent['text'])
        # print(sent['label'])

# %%
base_dir='./data/data158120'
tag_path="{}/trigger_tag.dict".format(base_dir)

data_dir="{}/trigger".format(base_dir)
train_data="{}/train.tsv".format(data_dir)
dev_data="{}/dev.tsv".format(data_dir)
test_data="{}/test.tsv".format(data_dir)

predict_data="{}/test.json".format(base_dir)

checkpoints="{}/trigger/".format(base_dir)
init_ckpt="{}/trigger/final.pdparams".format(base_dir)


do_train()
do_predict()
# Out:
# W0802 19:38:27.820214  1251 gpu_resources.cc:61] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 11.2, Runtime API Version: 10.1
# W0802 19:38:27.825275  1251 gpu_resources.cc:91] device: 0, cuDNN Version: 7.6.
# train epoch:0 - step:50 (total:3740) - loss:19.060974
# train epoch:0 - step:100 (total:3740) - loss:17.893379
# train epoch:0 - step:150 (total:3740) - loss:12.975210
# train epoch:0 - step:200 (total:3740) - loss:12.161092
# train epoch:0 - step:250 (total:3740) - loss:11.108285
# train epoch:0 - step:300 (total:3740) - loss:10.496643
# train epoch:0 - step:350 (total:3740) - loss:10.395264
# train epoch:1 - step:400 (total:3740) - loss:12.870819
# train epoch:1 - step:450 (total:3740) - loss:6.155119
# train epoch:1 - step:500 (total:3740) - loss:8.062029
# [2022-08-02 19:42:40,322] [ WARNING] - Compatibility Warning: The params of ChunkEvaluator.compute has been modified. The old version is `inputs`, `lengths`, `predictions`, `labels` while the current version is `lengths`, `predictions`, `labels`.  Please update the usage.
# dev step:500 - loss:7.47829,precision:0.46992,recall:0.39898,f1:0.43155current best 0.00000
# =======================save best model
# best performerence 0.43155
# train epoch:1 - step:550 (total:3740) - loss:5.317844
# train epoch:1 - step:600 (total:3740) - loss:5.892819
# train epoch:1 - step:650 (total:3740) - loss:4.675808
# train epoch:1 - step:700 (total:3740) - loss:4.136090
# train epoch:2 - step:750 (total:3740) - loss:2.785054
# train epoch:2 - step:800 (total:3740) - loss:5.592870
# train epoch:2 - step:850 (total:3740) - loss:2.949601
# train epoch:2 - step:900 (total:3740) - loss:3.880248
# train epoch:2 - step:950 (total:3740) - loss:4.166456
# train epoch:2 - step:1000 (total:3740) - loss:1.769350
# dev step:1000 - loss:3.57513,precision:0.76248,recall:0.67594,f1:0.71661current best 0.43155
# =======================save best model
# best performerence 0.71661
# train epoch:2 - step:1050 (total:3740) - loss:3.462531
# train epoch:2 - step:1100 (total:3740) - loss:3.368574
# train epoch:3 - step:1150 (total:3740) - loss:1.503188
# train epoch:3 - step:1200 (total:3740) - loss:2.465120
# train epoch:3 - step:1250 (total:3740) - loss:2.350885
# train epoch:3 - step:1300 (total:3740) - loss:2.246312
# train epoch:3 - step:1350 (total:3740) - loss:2.587715
# train epoch:3 - step:1400 (total:3740) - loss:0.896955
# train epoch:3 - step:1450 (total:3740) - loss:1.098979
# train epoch:4 - step:1500 (total:3740) - loss:2.368372
# dev step:1500 - loss:2.83737,precision:0.80374,recall:0.73212,f1:0.76626current best 0.71661
# =======================save best model
# best performerence 0.76626
# train epoch:4 - step:1550 (total:3740) - loss:1.802186
# train epoch:4 - step:1600 (total:3740) - loss:0.810405
# train epoch:4 - step:1650 (total:3740) - loss:0.738791
# train epoch:4 - step:1700 (total:3740) - loss:1.079043
# train epoch:4 - step:1750 (total:3740) - loss:0.990194
# train epoch:4 - step:1800 (total:3740) - loss:1.373730
# train epoch:4 - step:1850 (total:3740) - loss:1.343736
# train epoch:5 - step:1900 (total:3740) - loss:0.875147
# train epoch:5 - step:1950 (total:3740) - loss:0.483046
# train epoch:5 - step:2000 (total:3740) - loss:1.000923
# dev step:2000 - loss:2.66013,precision:0.77950,recall:0.76844,f1:0.77394current best 0.76626
# =======================save best model
# best performerence 0.77394
# train epoch:5 - step:2050 (total:3740) - loss:2.331722
# train epoch:5 - step:2100 (total:3740) - loss:0.468956
# train epoch:5 - step:2150 (total:3740) - loss:0.929455
# train epoch:5 - step:2200 (total:3740) - loss:0.893418
# train epoch:6 - step:2250 (total:3740) - loss:0.360293
# train epoch:6 - step:2300 (total:3740) - loss:1.442408
# train epoch:6 - step:2350 (total:3740) - loss:0.692803
# train epoch:6 - step:2400 (total:3740) - loss:0.432115
# train epoch:6 - step:2450 (total:3740) - loss:1.822824
# train epoch:6 - step:2500 (total:3740) - loss:0.606456
# dev step:2500 - loss:2.57336,precision:0.76078,recall:0.77072,f1:0.76572current best 0.77394
# train epoch:6 - step:2550 (total:3740) - loss:0.695669
# train epoch:6 - step:2600 (total:3740) - loss:0.692763
# train epoch:7 - step:2650 (total:3740) - loss:0.145790
# train epoch:7 - step:2700 (total:3740) - loss:0.219104
# train epoch:7 - step:2750 (total:3740) - loss:0.728366
# train epoch:7 - step:2800 (total:3740) - loss:0.469247
# train epoch:7 - step:2850 (total:3740) - loss:0.752810
# train epoch:7 - step:2900 (total:3740) - loss:0.976998
# train epoch:7 - step:2950 (total:3740) - loss:0.679309
# train epoch:8 - step:3000 (total:3740) - loss:0.270878
# dev step:3000 - loss:2.59641,precision:0.77032,recall:0.77469,f1:0.77250current best 0.77394
# train epoch:8 - step:3050 (total:3740) - loss:0.334302
# train epoch:8 - step:3100 (total:3740) - loss:0.222915
# train epoch:8 - step:3150 (total:3740) - loss:0.889505
# train epoch:8 - step:3200 (total:3740) - loss:0.970602
# train epoch:8 - step:3250 (total:3740) - loss:0.622007
# train epoch:8 - step:3300 (total:3740) - loss:0.461962
# train epoch:8 - step:3350 (total:3740) - loss:0.423171
# train epoch:9 - step:3400 (total:3740) - loss:0.245254
# train epoch:9 - step:3450 (total:3740) - loss:0.544834
# train epoch:9 - step:3500 (total:3740) - loss:0.248097
# dev step:3500 - loss:2.65715,precision:0.77288,recall:0.78604,f1:0.77940current best 0.77394
# =======================save best model
# best performerence 0.77940
# train epoch:9 - step:3550 (total:3740) - loss:0.278591
# train epoch:9 - step:3600 (total:3740) - loss:0.375325
# train epoch:9 - step:3650 (total:3740) - loss:0.048252
# train epoch:9 - step:3700 (total:3740) - loss:0.174443
# Loaded parameters from ./data/data158120/trigger/final.pdparams
#  step:50
# ==========
# <class 'str'>
# {"text": "振华三部曲的《暗恋橘生淮南》终于定档了，洛枳爱盛淮南谁也不知道，洛枳爱盛淮南其实全世界都知道。", "id": "a7c74f75eb8986377096b4dc62db217d", "pred": {"label": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "B-产品行为-上映", "I-产品行为-上映", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "腾讯收购《全境封锁》瑞典工作室 欲开发另类游戏大IP", "id": "1bf5de39669122e4458ed6db2cddc0c4", "pred": {"label": ["O", "O", "O", "I-财经/交易-出售/收购", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "6月22日，山外杯第四届全国体育院校篮球联赛（SCBA）在日照市山东外国语职业技术大学拉开战幕。", "id": "b98df49b32e4e9924c23bb0cd0c1e83d", "pred": {"label": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "I-组织行为-开幕", "O"]}}
# ==========
# <class 'str'>
# {"text": "e公司讯，工信部装备工业司发布2019年智能网联汽车标准化工作要点。", "id": "b73704c1d86084ef14d942168b310b1c", "pred": {"label": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "B-产品行为-发布", "I-产品行为-发布", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "新京报讯  5月7日，台湾歌手陈绮贞在社交网络上宣布，已于两年前与交往18年的男友、音乐人钟成虎分手。", "id": "9f7f677595a7f19ca16304a3d85ae94f", "pred": {"label": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "B-人生-分手", "I-人生-分手", "O"]}}
# ==========
# <class 'str'>
# {"text": "国际金价短期回调 后市银价有望出现较大涨幅", "id": "4d1f964593cd077f9171c09512974e8c", "pred": {"label": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "B-财经/交易-涨价", "O"]}}
# ==========
# <class 'str'>
# {"text": "央视名嘴韩乔生在赛前为中国男篮加油，期待球队展现英雄本色，输球后的韩乔生也相当无奈，他用3个“没有”来点评中国男篮，没有投手、没有经验、没有体力，实在太扎心。", "id": "6e62429b5f2e65c9f6a0052d6d1fa20d", "pred": {"label": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "B
"pred": {"label": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "在猛龙队夺得总冠军之后，莱昂纳德曾经向球队提出过续约的要求，那就是和雷霆队交易来保罗乔治，但是雷霆执意要得到西亚卡姆，最终猛龙队为了球队的未来放弃了这笔交易，所以猛龙队作出让步给西亚卡姆提供一份让他满意的合同的可能性非常大！", "id": "2335bdd9f818622702e8655d5b62c875", "pred": {"label": ["O", "O", "O", "O", "B-竞赛行为-夺冠", "I-竞赛行为-夺冠", "B-竞赛行为-夺冠", "I-竞赛行为-夺冠", "I-竞赛行为-夺冠", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "7月15日周一，统计局发布6月份70个大中城市商品住宅销售价格变动情况。", "id": "4d5e0a56a42a282f7b8bcfc2f904fd85", "pred": {"label": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "B-产品行为-发布", "I-产品行为-发布", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}

# %% [markdown]
# # 训练论元角色识别模型

# %%
base_dir='./data/data158120'
tag_path="{}/role_tag.dict".format(base_dir)

data_dir="{}/role".format(base_dir)
train_data="{}/train.tsv".format(data_dir)
dev_data="{}/dev.tsv".format(data_dir)
test_data="{}/test.tsv".format(data_dir)

predict_data="{}/test.json".format(base_dir)

checkpoints="{}/role/".format(base_dir)
init_ckpt="{}/role/final.pdparams".format(base_dir)

do_train()
do_predict()
# Out:
# train epoch:0 - step:50 (total:4350) - loss:89.512520
# train epoch:0 - step:100 (total:4350) - loss:74.403778
# train epoch:0 - step:150 (total:4350) - loss:85.160172
# train epoch:0 - step:200 (total:4350) - loss:94.533218
# train epoch:0 - step:250 (total:4350) - loss:73.825500
# train epoch:0 - step:300 (total:4350) - loss:70.997116
# train epoch:0 - step:350 (total:4350) - loss:62.695999
# train epoch:0 - step:400 (total:4350) - loss:73.339340
# train epoch:1 - step:450 (total:4350) - loss:54.493034
# train epoch:1 - step:500 (total:4350) - loss:48.933960
# [2022-08-02 20:16:31,320] [ WARNING] - Compatibility Warning: The params of ChunkEvaluator.compute has been modified. The old version is `inputs`, `lengths`, `predictions`, `labels` while the current version is `lengths`, `predictions`, `labels`.  Please update the usage.
# dev step:500 - loss:51.74525,precision:0.13764,recall:0.06313,f1:0.08656current best 0.00000
# =======================save best model
# best performerence 0.08656
# train epoch:1 - step:550 (total:4350) - loss:54.520622
# train epoch:1 - step:600 (total:4350) - loss:41.895187
# train epoch:1 - step:650 (total:4350) - loss:40.107841
# train epoch:1 - step:700 (total:4350) - loss:43.367210
# train epoch:1 - step:750 (total:4350) - loss:40.634727
# train epoch:1 - step:800 (total:4350) - loss:30.044048
# train epoch:1 - step:850 (total:4350) - loss:31.468550
# train epoch:2 - step:900 (total:4350) - loss:29.002758
# train epoch:2 - step:950 (total:4350) - loss:27.489361
# train epoch:2 - step:1000 (total:4350) - loss:32.105904
# dev step:1000 - loss:35.12398,precision:0.27836,recall:0.22701,f1:0.25008current best 0.08656
# =======================save best model
# best performerence 0.25008
# train epoch:2 - step:1050 (total:4350) - loss:30.729368
# train epoch:2 - step:1100 (total:4350) - loss:32.741585
# train epoch:2 - step:1150 (total:4350) - loss:29.099920
# train epoch:2 - step:1200 (total:4350) - loss:23.677429
# train epoch:2 - step:1250 (total:4350) - loss:26.228994
# train epoch:2 - step:1300 (total:4350) - loss:21.308506
# train epoch:3 - step:1350 (total:4350) - loss:19.843363
# train epoch:3 - step:1400 (total:4350) - loss:25.363295
# train epoch:3 - step:1450 (total:4350) - loss:24.035009
# train epoch:3 - step:1500 (total:4350) - loss:17.499897
# dev step:1500 - loss:29.34915,precision:0.32986,recall:0.31293,f1:0.32117current best 0.25008
# =======================save best model
# best performerence 0.32117
# train epoch:3 - step:1550 (total:4350) - loss:22.692482
# train epoch:3 - step:1600 (total:4350) - loss:26.405491
# train epoch:3 - step:1650 (total:4350) - loss:27.383427
# train epoch:3 - step:1700 (total:4350) - loss:21.039499
# train epoch:4 - step:1750 (total:4350) - loss:21.410240
# train epoch:4 - step:1800 (total:4350) - loss:20.300556
# train epoch:4 - step:1850 (total:4350) - loss:20.821911
# train epoch:4 - step:1900 (total:4350) - loss:18.130701
# train epoch:4 - step:1950 (total:4350) - loss:14.353343
# train epoch:4 - step:2000 (total:4350) - loss:18.555477
# dev step:2000 - loss:25.61691,precision:0.39019,recall:0.34724,f1:0.36747current best 0.32117
# =======================save best model
# best performerence 0.36747
# train epoch:4 - step:2050 (total:4350) - loss:24.415712
# train epoch:4 - step:2100 (total:4350) - loss:19.950745
# train epoch:4 - step:2150 (total:4350) - loss:19.408710
# train epoch:5 - step:2200 (total:4350) - loss:13.220895
# train epoch:5 - step:2250 (total:4350) - loss:17.154415
# train epoch:5 - step:2300 (total:4350) - loss:14.314455
# train epoch:5 - step:2350 (total:4350) - loss:10.371130
# train epoch:5 - step:2400 (total:4350) - loss:20.123032
# train epoch:5 - step:2450 (total:4350) - loss:16.003391
# train epoch:5 - step:2500 (total:4350) - loss:12.798049
# dev step:2500 - loss:23.71906,precision:0.41967,recall:0.38649,f1:0.40240current best 0.36747
# =======================save best model
# best performerence 0.40240
# train epoch:5 - step:2550 (total:4350) - loss:19.145828
# train epoch:5 - step:2600 (total:4350) - loss:15.734043
# train epoch:6 - step:2650 (total:4350) - loss:15.699568
# train epoch:6 - step:2700 (total:4350) - loss:17.159975
# train epoch:6 - step:2750 (total:4350) - loss:11.108143
# train epoch:6 - step:2800 (total:4350) - loss:15.365047
# train epoch:6 - step:2850 (total:4350) - loss:15.227507
# train epoch:6 - step:2900 (total:4350) - loss:13.588194
# train epoch:6 - step:2950 (total:4350) - loss:18.767927
# train epoch:6 - step:3000 (total:4350) - loss:22.441757
# dev step:3000 - loss:21.91578,precision:0.42653,recall:0.43426,f1:0.43036current best 0.40240
# =======================save best model
# best performerence 0.43036
# train epoch:7 - step:3050 (total:4350) - loss:12.187164
# train epoch:7 - step:3100 (total:4350) - loss:9.789943
# train epoch:7 - step:3150 (total:4350) - loss:9.109365
# train epoch:7 - step:3200 (total:4350) - loss:11.580469
# train epoch:7 - step:3250 (total:4350) - loss:15.868922
# train epoch:7 - step:3300 (total:4350) - loss:14.706062
# train epoch:7 - step:3350 (total:4350) - loss:8.253341
# train epoch:7 - step:3400 (total:4350) - loss:15.505158
# train epoch:7 - step:3450 (total:4350) - loss:15.306496
# train epoch:8 - step:3500 (total:4350) - loss:9.307400
# dev step:3500 - loss:21.05890,precision:0.42462,recall:0.46308,f1:0.44301current best 0.43036
# =======================save best model
# best performerence 0.44301
# train epoch:8 - step:3550 (total:4350) - loss:9.240422
# train epoch:8 - step:3600 (total:4350) - loss:10.425320
# train epoch:8 - step:3650 (total:4350) - loss:8.404804
# train epoch:8 - step:3700 (total:4350) - loss:10.003672
# train epoch:8 - step:3750 (total:4350) - loss:11.930993
# train epoch:8 - step:3800 (total:4350) - loss:15.020851
# train epoch:8 - step:3850 (total:4350) - loss:18.096838
# train epoch:8 - step:3900 (total:4350) - loss:9.420293
# train epoch:9 - step:3950 (total:4350) - loss:9.412477
# train epoch:9 - step:4000 (total:4350) - loss:9.981727
# dev step:4000 - loss:19.66200,precision:0.42792,recall:0.46528,f1:0.44582current best 0.44301
# =======================save best model
# best performerence 0.44582
# train epoch:9 - step:4050 (total:4350) - loss:6.983194
# train epoch:9 - step:4100 (total:4350) - loss:7.277029
# train epoch:9 - step:4150 (total:4350) - loss:10.988804
# train epoch:9 - step:4200 (total:4350) - loss:11.637749
# train epoch:9 - step:4250 (total:4350) - loss:6.082227
# train epoch:9 - step:4300 (total:4350) - loss:9.341994
# Loaded parameters from ./data/data158120/role/final.pdparams
#  step:50
# ==========
# <class 'str'>
# {"text": "振华三部曲的《暗恋橘生淮南》终于定档了，洛枳爱盛淮南谁也不知道，洛枳爱盛淮南其实全世界都知道。", "id": "a7c74f75eb8986377096b4dc62db217d", "pred": {"label": ["B-上映影视", "I-上映影视", "I-上映影视", "I-上映影视", "I-上映影视", "I-上映影视", "I-上映影视", "I-上映影视", "I-上映影视", "I-上映影视", "I-上映影视", "I-上映影视", "I-上映影视", "I-上映影视", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "腾讯收购《全境封锁》瑞典工作室 欲开发另类游戏大IP", "id": "1bf5de39669122e4458ed6db2cddc0c4", "pred": {"label": ["B-收购方", "I-收购方", "O", "O", "B-交易物", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "6月22日，山外杯第四届全国体育院校篮球联赛（SCBA）在日照市山东外国语职业技术大学拉开战幕。", "id": "b98df49b32e4e9924c23bb0cd0c1e83d", "pred": {"label": ["B-时间", "I-时间", "I-时间", "I-时间", "I-时间", "O", "B-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "O", "O", "O", "O", "I-地点", "I-地点", "I-地点", "I-地点", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "I-活动名称", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "e公司讯，工信部装备工业司发布2019年智能网联汽车标准化工作要点。", "id": "b73704c1d86084ef14d942168b310b1c", "pred": {"label": ["O", "O", "O", "O", "O", "B-发布方", "I-发布方", "I-发布方", "I-发布方", "I-发布方", "I-发布方", "I-发布方", "I-发布方", "O", "O", "B-发布产品", "I-发布产品", "I-发布产品", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "新京报讯  5月7日，台湾歌手陈绮贞在社交网络上宣布，已于两年前与交往18年的男友、音乐人钟成虎分手。", "id": "9f7f677595a7f19ca16304a3d85ae94f", "pred": {"label": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "B-分手双方", "I-分手双方", "I-分手双方", "I-分手双方", "I-分手双方", "I-分手双方", "I-分手双方", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "B-时间", "I-时间", "O", "O", "B-分手双方", "I-分手双方", "I-分手双方", "I-分手双方", "I-分手双方", "I-分手双方", "I-分手双方", "I-分手双方", "I-分手双方", "B-分手双方", "I-分手双方", "I-分手双方", "I-分手双方", "I-分手双方", "I-分手双方", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "国际金价短期回调 后市银价有望出现较大涨幅", "id": "4d1f964593cd077f9171c09512974e8c", "pred": {"label": ["B-涨价物", "I-涨价物", "I-涨价物", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "央视名嘴韩乔生在赛前为中国男篮加油，期待球队展现英雄本色，输球后的韩乔生也相当无奈，他用3个“没有”来点评中国男篮，没有投手、没有经验、没有体力，实在太扎心。", "id": "6e62429b5f2e65c9f6a0052d6d1fa20d", "pred": {"label": ["B-结婚双方", "I-结婚双方", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "8月31日，第四届两岸关系天府论坛在四川眉山市举行。", "id": "af0185e53b0512bcb5909a20bf3ce1c5", "pred": {"label": ["B-时间", "I-时间", "I-时间", "I-时间", "I-时间", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "B
", "pred": {"label": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "B-胜者", "I-胜者", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "中国高科拟购英腾教育 是否会出现大规模退款受关注", "id": "2adbe1af31051ca353f404f09d4ede8e", "pred": {"label": ["O", "O", "O", "O", "O", "O", "B-交易物", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "国家艺术基金艺术结构课题组编著的《艺术成本结构调研报告》(以下称《报告》)由文化艺术出版社出版发行。", "id": "3d0ab452646787f5d004a9541221a6ab", "pred": {"label": ["B-发布方", "I-发布方", "I-发布方", "I-发布方", "I-发布方", "I-发布方", "I-发布方", "O", "O", "O", "O", "O", "O", "O", "O", "O", "B-交易物", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "O", "O", "O", "B-交易物", "I-交易物", "I-交易物", "O", "O", "O", "B-发布产品", "I-发布产品", "I-发布产品", "I-交易物", "I-交易物", "I-交易物", "I-交易物", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "最终双方大战两个加时才分出胜负。", "id": "d417ab0761301220d35522f42d717821", "pred": {"label": ["O", "O", "B-胜者", "I-胜者", "I-胜者", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "“双红会”「曼联VS利物浦」利物浦打败客场不胜曼联的魔咒", "id": "afc1ba7dc2e6d03db10a81d816f61505", "pred": {"label": ["B-赛事名称", "I-赛事名称", "I-赛事名称", "I-赛事名称", "O", "O", "B-败者", "I-败者", "I-败者", "I-败者", "I-败者", "I-败者", "I-败者", "O", "B-胜者", "I-胜者", "I-胜者", "O", "O", "O", "O", "O", "O", "B-败者", "I-败者", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "贝尔竟索梅西C罗式的年薪 签字费2000万镑+霸王条款才会来中超", "id": "321f3475810217a8364c1dc199b9a8b4", "pred": {"label": ["B-加盟者", "I-加盟者", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "任正非为何同意将5G技术出售给美国？", "id": "c40650a2014a84d2d2e8bcfd2b19bf98", "pred": {"label": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "10月3日，永兴派出所接到警情，永安村沟北三队出现一只疯狗，已经咬伤多名儿童和数只家禽，涉事狗还在附近村庄流窜。", "id": "734b8c1cdf9da3325b573426d8addbff", "pred": {"label": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "B-地点", "I-游行组织", "I-游行组织", "I-游行组织", "I-游行组织", "I-游行组织", "I-游行组织", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "B-地点", "I-地点", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "近日，宣威市公安局合成作战中心及田坝、海岱等派出所多警种联合，成功打掉一盗窃团伙，抓获犯罪嫌疑人3人，破获了近期发生在田坝镇的系列盗窃鸡、羊、火腿等物品案件。", "id": "52435e0fa40f9f4073010ad2e9cfa142", "pred": {"label": ["B-时间", "I-时间", "O", "B-拘捕者", "I-拘捕者", "I-拘捕者", "I-拘捕者", "I-拘捕者", "I-拘捕者", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "I-拘捕者", "I-拘捕者", "I-拘捕者", "I-拘捕者", "I-拘捕者", "I-拘捕者", "I-拘捕者", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "B-被拘捕者", "I-被拘捕者", "I-被拘捕者", "I-被拘捕者", "I-被拘捕者", "I-被拘捕者", "I-被拘捕者", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "「ST沪科」大幅拉升1.97% 股价创近2个月新高", "id": "c0a8609bf6b6fce1115fa76eba6e1d2b", "pred": {"label": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "辅仁药业遭证监会火速立案 监管合力严管违规乱象", "id": "d3739282bf21ae36f8b956999beff5e5", "pred": {"label": ["B-立案对象", "I-立案对象", "I-立案对象", "I-立案对象", "O", "B-立案机构", "I-立案机构", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "2019年斯诺克世锦赛半决赛即将打响，身为“七五三杰”之一的希金斯将迎战赛会16号种子吉尔伯特，半决赛采取33局17胜制，希金斯在第十次闯入半决赛之后，力争连续三年杀进决赛，继续向世锦赛五冠王发球冲击。", "id": "81864af52d27d421a2a8fed44111ca85", "pred": {"label": ["B-赛事名称", "I-晋级赛事", "I-晋级赛事", "I-晋级赛事", "I-晋级赛事", "I-晋级赛事", "I-晋级赛事", "I-晋级赛事", "I-晋级赛事", "I-晋级赛事", "I-晋级赛事", "I-晋级赛事", "I-晋级赛事", "I-晋级赛事", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "赛斯：现在要打败他，但会追赶他！", "id": "e5b7378f3380f9333179fb15fd8a439d", "pred": {"label": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text":
"O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "「已寻回」11岁男孩在湖南省邵阳市邵阳县走失", "id": "e644147eaea1a9cba08d9ce962613e42", "pred": {"label": ["O", "O", "O", "O", "O", "B-失联者", "I-失联者", "I-失联者", "I-失联者", "I-失联者", "O", "B-地点", "I-地点", "I-地点", "I-地点", "I-地点", "I-地点", "I-地点", "I-地点", "I-地点", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "永远少一只！妈揪偷袜大盗 惯犯喵撤场前不忘望向镜头", "id": "90f6d0172b5a45dcc9b0b7e652c6f60f", "pred": {"label": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "货车追尾城管车，司机：他拉走了我两车瓜，城管：我故意踩慢的", "id": "0fbd5b2321a52c8b1a580a5481f49a33", "pred": {"label": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "相信经常关注通信行业的小伙伴都知道，今年下半年的通信行业十分的“热闹”，5G套餐的预约、5G套餐资费11月1日正式公布、流量畅享套餐的停售、携号转网11月30全面普及等等消息都挤到了一起，而随着携号转网和5G的即将来临，国内的三家运营商对于市场和用户的争夺也是进入了白热化，各自都在推出各种惠民的活动，试图能够抢夺更大的市场，就连一向被网友吐槽抠门的移动也不例外。", "id": "20abb32653a37fc1d7c75e334fe6a924", "pred": {"label": ["O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "B-发布产品", "I-发布产品"]}}
# ==========
# <class 'str'>
# {"text": "在猛龙队夺得总冠军之后，莱昂纳德曾经向球队提出过续约的要求，那就是和雷霆队交易来保罗乔治，但是雷霆执意要得到西亚卡姆，最终猛龙队为了球队的未来放弃了这笔交易，所以猛龙队作出让步给西亚卡姆提供一份让他满意的合同的可能性非常大！", "id": "2335bdd9f818622702e8655d5b62c875", "pred": {"label": ["O", "B-冠军", "I-冠军", "I-冠军", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}
# ==========
# <class 'str'>
# {"text": "7月15日周一，统计局发布6月份70个大中城市商品住宅销售价格变动情况。", "id": "4d5e0a56a42a282f7b8bcfc2f904fd85", "pred": {"label": ["B-时间", "I-时间", "I-时间", "I-时间", "I-时间", "I-时间", "I-时间", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}}

# %% [markdown]
# # 预测

# %% [markdown]
# # 触发器预测

# %%
# base_dir='./data/data158120'
# tag_path="{}/trigger_tag.dict".format(base_dir)

# data_dir="{}/trigger".format(base_dir)
# train_data="{}/train.tsv".format(data_dir)
# dev_data="{}/dev.tsv".format(data_dir)
# test_data="{}/test.tsv".format(data_dir)

# predict_data="{}/test.json".format(base_dir)

# checkpoints="{}/trigger/".format(base_dir)
# init_ckpt="{}/trigger/best.pdparams".format(base_dir)



# import numpy as np
# from paddlenlp.layers import LinearChainCrfLoss,ViterbiDecoder,LinearChainCrf
# from functools import partial
# from paddlenlp.data import Stack,Tuple,Pad
# from paddlenlp.metrics import ChunkEvaluator
# import paddle
# do_predict()

# %% [markdown]
# # 角色预测

# %%
# base_dir='./data/data158120'
# tag_path="{}/role_tag.dict".format(base_dir)

# data_dir="{}/role".format(base_dir)
# train_data="{}/train.tsv".format(data_dir)
# dev_data="{}/dev.tsv".format(data_dir)
# test_data="{}/test.tsv".format(data_dir)

# predict_data="{}/test.json".format(base_dir)

# checkpoints="{}/role/".format(base_dir)
# init_ckpt="{}/role/final.pdparams".format(base_dir)

# do_predict()
