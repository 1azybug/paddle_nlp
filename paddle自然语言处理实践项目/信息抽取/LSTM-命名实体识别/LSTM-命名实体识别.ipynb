# %%
from paddlenlp.datasets import load_dataset
train_ds,dev_ds,test_ds =load_dataset(
    'msra_ner',splits=('train','test','test'),lazy=False
)

# %%
label_vocab={label:ind for ind,label in enumerate(train_ds.label_list)}

# %%
train_ds.label_list
# Out:
# ['B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC', 'O']

# %%
label_vocab
# Out:
# {'B-PER': 0,
#  'I-PER': 1,
#  'B-ORG': 2,
#  'I-ORG': 3,
#  'B-LOC': 4,
#  'I-LOC': 5,
#  'O': 6}

# %%
words=set()
word_vocab=[]
for item in train_ds:
    # print(item)
    word_vocab+=item['tokens']
print(len(list(word_vocab)),len(set(word_vocab)))
word_vocab={k:v+2 for v,k in enumerate(set(word_vocab))}
word_vocab['PAD']=0
word_vocab['OOV']=1
# Out:
# 2171516 4790

# %%
len(train_ds),len(list(word_vocab))
# Out:
# (45000, 4792)

# %%
def convert_tokens_to_ids(tokens,vocab,oov_token='OOV'):
    token_ids=[]
    oov_id=vocab.get(oov_token) if oov_token else None
    for token in tokens:
        token_id=vocab.get(token,oov_id)
        token_ids.append(token_id)
    return token_ids

def convert_example(example):
    tokens,labels=example['tokens'],example['labels']
    token_ids=convert_tokens_to_ids(tokens,word_vocab,"OOV")
    label_ids=labels
    return token_ids,len(token_ids),label_ids

# %%
train_ds.map(convert_example)
dev_ds.map(convert_example)
test_ds.map(convert_example)

# %%
list(train_ds)[:10]
# Out:
# [([3079,
#    1127,
#    209,
#    1133,
#    2737,
#    851,
#    667,
#    4212,
#    4608,
#    2800,
#    4596,
#    1696,
#    3035,
#    4359,
#    104,
#    775,
#    2075,
#    1281,
#    672,
#    192,
#    3583,
#    693,
#    2529,
#    3035,
#    3869,
#    1375,
#    2075,
#    737,
#    457,
#    4103,
#    1249,
#    15,
#    2113,
#    1742,
#    4212,
#    4305,
#    571,
#    1729,
#    812,
#    2075,
#    709,
#    1787,
#    2236,
#    2110,
#    571,
#    522,
#    1118,
#    3079,
#    3498,
#    3458],
#   50,
#   [6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6]),
#  ([15,
#    4305,
#    881,
#    775,
#    2236,
#    4764,
#    4106,
#    4103,
#    2912,
#    3905,
#    1249,
#    15,
#    2185,
#    3760,
#    2622,
#    4212,
#    3564,
#    4646,
#    3689,
#    2044,
#    2075,
#    533,
#    4764,
#    963,
#    3193,
#    2242,
#    1882,
#    4253,
#    618,
#    4212,
#    1375,
#    2028,
#    3365,
#    3326,
#    2709,
#    682,
#    4011],
#   37,
#   [6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6]),
#  ([1420,
#    4103,
#    1607,
#    1787,
#    2376,
#    1563,
#    1630,
#    4750,
#    2440,
#    2521,
#    3533,
#    1328,
#    4706,
#    2075,
#    15,
#    4220,
#    3447,
#    813,
#    2171,
#    2681,
#    2075,
#    2568,
#    4764,
#    963,
#    3193,
#    1249,
#    15,
#    2882,
#    1630,
#    2887,
#    265,
#    2622,
#    4212,
#    4188,
#    702,
#    3573,
#    4646,
#    4011],
#   38,
#   [6,
#    6,
#    6,
#    4,
#    6,
#    6,
#    4,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    4,
#    5,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6]),
#  

#   [6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6]),
#  ([4725,
#    2241,
#    3690,
#    2350,
#    3866,
#    3690,
#    1635,
#    4505,
#    3690,
#    276,
#    3729,
#    2737,
#    3182,
#    3252,
#    4764,
#    2581,
#    3745,
#    4212,
#    1066,
#    1849,
#    4011],
#   21,
#   [6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6]),
#  ([15,
#    4305,
#    4212,
#    1363,
#    3745,
#    3174,
#    3506,
#    1118,
#    2888,
#    419,
#    889,
#    1249,
#    15,
#    4212,
#    2581,
#    3745,
#    2075,
#    2798,
#    1118,
#    4764,
#    1133,
#    3487,
#    859,
#    4212,
#    3535,
#    1624,
#    14,
#    2300,
#    4011],
#   29,
#   [6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6,
#    6]),
#  ([4305,
#    4275,
#    1054,
#    4523,
#    3605,
#    94,
#    2075,
#    1138,
#    1880,
#    2340,
#    4212,
#    4725,
#    3623,
#    551,
#    4237,
#    3623,
#    1118,
#    2764,
#    2888,
#    3151,
#    2709,
#    1549,
#    3573,
#    4011],
#   24,
#   [6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6])]

# %%
import paddle
from paddlenlp.data import Tuple,Stack,Pad


batchify_fn=lambda samples,fn=Tuple(
    Pad(axis=0,pad_val=word_vocab.get('OOV')),
    Stack(),
    Pad(axis=0,pad_val=label_vocab.get("O"))
):fn(samples)


train_loader=paddle.io.DataLoader(
    dataset=train_ds,batch_size=32,shuffle=True,drop_last=True,collate_fn=batchify_fn
)

dev_loader=paddle.io.DataLoader(
    dataset=dev_ds,batch_size=32,shuffle=True,drop_last=True,collate_fn=batchify_fn
)

test_loader=paddle.io.DataLoader(
    dataset=test_ds,batch_size=32,shuffle=True,drop_last=True,collate_fn=batchify_fn
)

# %%
import paddle.nn as nn
from paddlenlp.layers import LinearChainCrf,ViterbiDecoder,LinearChainCrfLoss
from paddlenlp.metrics import ChunkEvaluator
class BiLSTMWithCRF(nn.Layer):
    def __init__(self,emb_size,hidden_size,word_num,label_num,use_w2v_emb=False):
        super(BiLSTMWithCRF,self).__init__()
        self.word_emb=nn.Embedding(word_num,emb_size)
        self.lstm=nn.LSTM(emb_size,hidden_size,num_layers=2,direction='bidirectional')
        self.fc=nn.Linear(hidden_size*2,label_num+2) #BOS EOS
        self.crf=LinearChainCrf(label_num)
        self.decoder=ViterbiDecoder(self.crf.transitions)
    
    def forward(self,x,lens):
        embs=self.word_emb(x)
        output,_=self.lstm(embs)
        output=self.fc(output)
        _,pred=self.decoder(output,lens)

        return output,lens,pred

# %% [markdown]
# # 训练

# %%
network=BiLSTMWithCRF(300,300,len(word_vocab),len(label_vocab))
# Out:
# W0801 06:45:43.317390   870 gpu_resources.cc:61] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 11.2, Runtime API Version: 10.1
# W0801 06:45:43.323509   870 gpu_resources.cc:91] device: 0, cuDNN Version: 7.6.

# %%
model=paddle.Model(network)

# %%
optimizer=paddle.optimizer.Adam(learning_rate=0.001,parameters=model.parameters())
crf_loss=LinearChainCrfLoss(network.crf)
chunk_evaluator=ChunkEvaluator(label_list=label_vocab.keys(),suffix=True)

# %%
model.prepare(optimizer,crf_loss,chunk_evaluator)
model.fit(train_data=train_loader,eval_data=dev_loader,epochs=10,save_dir='./results',log_freq=100)
# Out:
# The loss value printed in the log is the current step, and the metric is the average value of previous steps.
# Epoch 1/10
# [2022-08-01 06:45:46,223] [ WARNING] - Compatibility Warning: The params of LinearChainCrfLoss.forward has been modified. The third param is `labels`, and the fourth is not necessary. Please update the usage.
# [2022-08-01 06:45:46,328] [ WARNING] - Compatibility Warning: The params of ChunkEvaluator.compute has been modified. The old version is `inputs`, `lengths`, `predictions`, `labels` while the current version is `lengths`, `predictions`, `labels`.  Please update the usage.
# step  100/1406 - loss: 15.6692 - precision: 0.3257 - recall: 0.1225 - f1: 0.1780 - 439ms/step
# step  200/1406 - loss: 42.9053 - precision: 0.5106 - recall: 0.3059 - f1: 0.3826 - 425ms/step
# step  300/1406 - loss: 4.7607 - precision: 0.5801 - recall: 0.4049 - f1: 0.4769 - 440ms/step
# step  400/1406 - loss: 0.0000e+00 - precision: 0.6189 - recall: 0.4667 - f1: 0.5321 - 469ms/step
# step  500/1406 - loss: 0.0828 - precision: 0.6484 - recall: 0.5142 - f1: 0.5735 - 472ms/step
# step  600/1406 - loss: 0.0000e+00 - precision: 0.6709 - recall: 0.5494 - f1: 0.6041 - 470ms/step
# step  700/1406 - loss: 2.4946 - precision: 0.6878 - recall: 0.5760 - f1: 0.6270 - 472ms/step
# step  800/1406 - loss: 0.0000e+00 - precision: 0.7020 - recall: 0.5986 - f1: 0.6462 - 470ms/step
# step  900/1406 - loss: 0.2968 - precision: 0.7146 - recall: 0.6188 - f1: 0.6633 - 475ms/step
# step 1000/1406 - loss: 1.9320 - precision: 0.7236 - recall: 0.6351 - f1: 0.6765 - 479ms/step
# step 1100/1406 - loss: 2.5171 - precision: 0.7336 - recall: 0.6503 - f1: 0.6894 - 477ms/step
# step 1200/1406 - loss: 0.1423 - precision: 0.7427 - recall: 0.6642 - f1: 0.7012 - 477ms/step
# step 1300/1406 - loss: 5.9721 - precision: 0.7511 - recall: 0.6768 - f1: 0.7120 - 477ms/step
# step 1400/1406 - loss: 1.5230 - precision: 0.7586 - recall: 0.6883 - f1: 0.7217 - 478ms/step
# step 1406/1406 - loss: 10.4843 - precision: 0.7592 - recall: 0.6889 - f1: 0.7223 - 478ms/step
# save checkpoint at /home/aistudio/results/0
# Eval begin...
# step 100/107 - loss: 7.0578 - precision: 0.7945 - recall: 0.7506 - f1: 0.7719 - 454ms/step
# step 107/107 - loss: 0.0000e+00 - precision: 0.7982 - recall: 0.7567 - f1: 0.7769 - 451ms/step
# Eval samples: 3424
# Epoch 2/10
# step  100/1406 - loss: 4.5899 - precision: 0.8371 - recall: 0.8255 - f1: 0.8313 - 518ms/step
# step  200/1406 - loss: 0.0000e+00 - precision: 0.8452 - recall: 0.8383 - f1: 0.8418 - 495ms/step
# step  300/1406 - loss: 0.0000e+00 - precision: 0.8521 - recall: 0.8458 - f1: 0.8489 - 499ms/step
# step  400/1406 - loss: 0.0000e+00 - precision: 0.8546 - recall: 0.8493 - f1: 0.8519 - 501ms/step
# step  500/1406 - loss: 2.8516 - precision: 0.8567 - recall: 0.8514 - f1: 0.8540 - 502ms/step
# step  600/1406 - loss: 2.0114 - precision: 0.8583 - recall: 0.8529 - f1: 0.8556 - 493ms/step
# step  700/1406 - loss: 0.0000e+00 - precision: 0.8598 - recall: 0.8543 - f1: 0.8570 - 493ms/step
# step  800/1406 - loss: 0.1920 - precision: 0.8619 - recall: 0.8562 - f1: 0.8591 - 492ms/step
# step  900/1406 - loss: 7.4308 - precision: 0.8626 - recall: 0.8578 - f1: 0.8602 - 493ms/step
# step 1000/1406 - loss: 5.7296 - precision: 0.8640 - recall: 0.8594 - f1: 0.8617 - 493ms/step
# step 1100/1406 - loss: 0.0000e+00 - precision: 0.8653 - recall: 0.8616 - f1: 0.8635 - 488ms/step
# step 1200/1406 - loss: 0.0000e+00 - precision: 0.8660 - recall: 0.8626 - f1: 0.8643 - 482ms/step
# step 1300/1406 - loss: 0.0000e+00 - precision: 0.8671 - recall: 0.8644 - f1: 0.8657 - 479ms/step
# step 1400/1406 - loss: 0.0000e+00 - precision: 0.8677 - recall: 0.8657 - f1: 0.8667 - 479ms/step
# step 1406/1406 - loss: 0.0000e+00 - precision: 0.8680 - recall: 0.8659 - f1: 0.8669 - 478ms/step
# save checkpoint at /home/aistudio/results/1
# Eval begin...
# step 100/107 - loss: 0.0000e+00 - precision: 0.8525 - recall: 0.8062 - f1: 0.8287 - 429ms/step
# step 107/107 - loss: 0.0000e+00 - precision: 0.8529 - recall: 0.8069 - f1: 0.8293 - 446ms/step
# Eval samples: 3424
# Epoch 3/10
# step  100/1406 - loss: 0.0000e+00 - precision: 0.8938 - recall: 0.9047 - f1: 0.8992 - 448ms/step
# step  200/1406 - loss: 2.4092 - precision: 0.8947 - recall: 0.9050 - f1: 0.8998 - 450ms/step
# step  300/1406 - loss: 0.0000e+00 - precision: 0.8972 - recall: 0.9065 - f1: 0.9018 - 463ms/step
# step  400/1406 - loss: 0.0000e+00 - precision: 0.8970 - recall: 0.9070 - f1: 0.9020 - 463ms/step
# step  500/1406 - loss: 0.0000e+00 - precision: 0.8972 - recall: 0.9072 - f1: 0.9022 - 469ms/step
# step  600/1406 - loss: 0.0000e+00 - precision: 0.8959 - recall: 0.9060 - f1: 0.9009 - 466ms/step
# step  700/1406 - loss: 0.0000e+00 - precision: 0.8939 - recall: 0.9043 - f1: 0.8991 - 462ms/step
# step  800/1406 - loss: 0.4644 - precision: 0.8931 - recall: 0.9038 - f1: 0.8984 - 462ms/step
# step  900/1406 - loss: 0.0000e+00 - precision: 0.8919 - recall: 0.9033 - f1: 0.8976 - 460ms/step
# step 1000/1406 - loss: 0.0000e+00 - precision: 0.8923 - recall: 0.9034 - f1: 0.8978 - 457ms/step
# step 1100/1406 - loss: 2.2707 - precision: 0.8919 - recall: 0.9037 - f1: 0.8978 - 463ms/step
# step 1200/1406 - loss: 1.6216 - precision: 0.8923 - recall: 0.9045 - f1: 0.8984 - 461ms/step
# step 1300/1406 - loss: 0.0000e+00 - precision: 0.8913 - recall: 0.9035 - f1: 0.8974 - 468ms/step
# step 1400/1406 - loss: 0.0000e+00 - precision: 0.8909 - recall: 0.9035 - f1: 0.8971 - 473ms/step
# step 1406/1406 - loss: 0.0000e+00 - precision: 0.8909 - recall: 0.9035 - f1: 0.8971 - 473ms/step
# save checkpoint at /home/aistudio/results/2
# Eval begin...
# step 100/107 - loss: 0.7218 - precision: 0.8689 - recall: 0.8457 - f1: 0.8572 - 445ms/step
# step 107/107 - loss: 7.8887 - precision: 0.8700 - recall: 0.8444 - f1: 0.8570 - 449ms/step
# Eval samples: 3424
# Epoch 4/10
# step  100/1406 - loss: 0.0000e+00 - precision: 0.9051 - recall: 0.9208 - f1: 0.9129 - 467ms/step
# step  200/1406 - loss: 0.0000e+00 - precision: 0.9065 - recall: 0.9234 - f1: 0.9148 - 458ms/step
# step  300/1406 - loss: 0.0000e+00 - precision: 0.9082 - recall: 0.9225 - f1: 0.9153 - 474ms/step
# step  400/1406 - loss: 0.0000e+00 - precision: 0.9071 - recall: 0.9231 - f1: 0.9150 - 478ms/step
# step  500/1406 - loss: 0.0000e+00 - precision: 0.9069 - recall: 0.9227 - f1: 0.9147 - 476ms/step
# step  600/1406 - loss: 0.0000e+00 - precision: 0.9068 - recall: 0.9226 - f1: 0.9146 - 473ms/step
# step  700/1406 - loss: 1.3880 - precision: 0.9060 - recall: 0.9222 - f1: 0.9141 - 470ms/step
# step  800/1406 - loss: 0.0000e+00 - precision: 0.9057 - recall: 0.9227 - f1: 0.9141 - 466ms/step
# step  900/1406 - loss: 0.1517 - precision: 0.9056 - recall: 0.9234 - f1: 0.9144 - 465ms/step
# step 1000/1406 - loss: 0.0000e+00 - precision: 0.9044 - recall: 0.9229 - f1: 0.9136 - 467ms/step
# step 1100/1406 - loss: 0.0000e+00 - precision: 0.9047 - recall: 0.9228 - f1: 0.9137 - 468ms/step
# step 1200/1406 - loss: 0.2581 - precision: 0.9033 - recall: 0.9224 - f1: 0.9127 - 470ms/step
# step 1300/1406 - loss: 0.0000e+00 - precision: 0.9020 - recall: 0.9219 - f1: 0.9118 - 471ms/step
# step 1400/1406 - loss: 0.0000e+00 - precision: 0.9020 - recall: 0.9221 - f1: 0.9119 - 467ms/step
# step 1406/1406 - loss: 0.0000e+00 - precision: 0.9020 - recall: 0.9222 - f1: 0.9120 - 469ms/step
# save checkpoint at /home/aistudio/results/3
# Eval begin...
# step 100/107 - loss: 0.0000e+00 - precision: 0.8544 - recall: 0.8527 - f1: 0.8535 - 446ms/step
# step 107/107 - loss: 0.0000e+00 - precision: 0.8545 - recall: 0.8534 - f1: 0.8539 - 438ms/step
# Eval samples: 3424
# Epoch 5/10
# step  100/1406 - loss: 0.0000e+00 - precision: 0.9153 - recall: 0.9385 - f1: 0.9267 - 478ms/step
# step  200/1406 - loss: 2.1312 - precision: 0.9155 - recall: 0.9390 - f1: 0.9271 - 460ms/step
# step  300/1406 - loss: 0.0000e+00 - precision: 0
# Eval begin...
# step 100/107 - loss: 0.0000e+00 - precision: 0.8423 - recall: 0.8487 - f1: 0.8455 - 442ms/step
# step 107/107 - loss: 0.0000e+00 - precision: 0.8408 - recall: 0.8465 - f1: 0.8436 - 442ms/step
# Eval samples: 3424
# Epoch 8/10
# step  100/1406 - loss: 0.0000e+00 - precision: 0.8919 - recall: 0.9326 - f1: 0.9118 - 470ms/step
# step  200/1406 - loss: 0.0000e+00 - precision: 0.8959 - recall: 0.9327 - f1: 0.9139 - 490ms/step
# step  300/1406 - loss: 0.0000e+00 - precision: 0.8978 - recall: 0.9339 - f1: 0.9155 - 479ms/step
# step  400/1406 - loss: 0.0000e+00 - precision: 0.8959 - recall: 0.9349 - f1: 0.9150 - 472ms/step
# step  500/1406 - loss: 0.0000e+00 - precision: 0.8943 - recall: 0.9363 - f1: 0.9148 - 472ms/step
# step  600/1406 - loss: 0.0000e+00 - precision: 0.8929 - recall: 0.9367 - f1: 0.9143 - 469ms/step
# step  700/1406 - loss: 0.0000e+00 - precision: 0.8946 - recall: 0.9369 - f1: 0.9153 - 471ms/step
# step  800/1406 - loss: 0.0000e+00 - precision: 0.8927 - recall: 0.9364 - f1: 0.9140 - 468ms/step
# step  900/1406 - loss: 0.0000e+00 - precision: 0.8917 - recall: 0.9365 - f1: 0.9135 - 471ms/step
# step 1000/1406 - loss: 0.0000e+00 - precision: 0.8909 - recall: 0.9359 - f1: 0.9128 - 470ms/step
# step 1100/1406 - loss: 0.0000e+00 - precision: 0.8913 - recall: 0.9354 - f1: 0.9128 - 472ms/step
# step 1200/1406 - loss: 0.0000e+00 - precision: 0.8909 - recall: 0.9355 - f1: 0.9127 - 473ms/step
# step 1300/1406 - loss: 0.0000e+00 - precision: 0.8904 - recall: 0.9349 - f1: 0.9121 - 472ms/step
# step 1400/1406 - loss: 0.0445 - precision: 0.8893 - recall: 0.9344 - f1: 0.9113 - 475ms/step
# step 1406/1406 - loss: 0.0000e+00 - precision: 0.8894 - recall: 0.9344 - f1: 0.9114 - 475ms/step
# save checkpoint at /home/aistudio/results/7
# Eval begin...
# step 100/107 - loss: 0.0000e+00 - precision: 0.8451 - recall: 0.8707 - f1: 0.8577 - 442ms/step
# step 107/107 - loss: 0.0000e+00 - precision: 0.8443 - recall: 0.8706 - f1: 0.8573 - 434ms/step
# Eval samples: 3424
# Epoch 9/10
# step  100/1406 - loss: 0.0000e+00 - precision: 0.8858 - recall: 0.9348 - f1: 0.9096 - 452ms/step
# step  200/1406 - loss: 0.0000e+00 - precision: 0.8854 - recall: 0.9374 - f1: 0.9107 - 441ms/step
# step  300/1406 - loss: 0.0000e+00 - precision: 0.8860 - recall: 0.9390 - f1: 0.9117 - 470ms/step
# step  400/1406 - loss: 0.0000e+00 - precision: 0.8883 - recall: 0.9386 - f1: 0.9128 - 478ms/step
# step  500/1406 - loss: 0.0000e+00 - precision: 0.8880 - recall: 0.9380 - f1: 0.9123 - 480ms/step
# step  600/1406 - loss: 0.0000e+00 - precision: 0.8870 - recall: 0.9369 - f1: 0.9113 - 481ms/step
# step  700/1406 - loss: 0.0000e+00 - precision: 0.8882 - recall: 0.9364 - f1: 0.9117 - 476ms/step
# step  800/1406 - loss: 0.0000e+00 - precision: 0.8886 - recall: 0.9361 - f1: 0.9117 - 478ms/step
# step  900/1406 - loss: 0.0000e+00 - precision: 0.8887 - recall: 0.9355 - f1: 0.9115 - 475ms/step
# step 1000/1406 - loss: 0.0000e+00 - precision: 0.8870 - recall: 0.9348 - f1: 0.9102 - 483ms/step
# step 1100/1406 - loss: 0.0000e+00 - precision: 0.8862 - recall: 0.9343 - f1: 0.9096 - 478ms/step
# step 1200/1406 - loss: 0.0000e+00 - precision: 0.8855 - recall: 0.9338 - f1: 0.9090 - 477ms/step
# step 1300/1406 - loss: 0.0000e+00 - precision: 0.8862 - recall: 0.9336 - f1: 0.9093 - 478ms/step
# step 1400/1406 - loss: 0.0000e+00 - precision: 0.8850 - recall: 0.9330 - f1: 0.9084 - 482ms/step
# step 1406/1406 - loss: 0.0000e+00 - precision: 0.8849 - recall: 0.9329 - f1: 0.9082 - 482ms/step
# save checkpoint at /home/aistudio/results/8
# Eval begin...
# step 100/107 - loss: 3.1237 - precision: 0.8145 - recall: 0.8488 - f1: 0.8313 - 444ms/step
# step 107/107 - loss: 0.0000e+00 - precision: 0.8141 - recall: 0.8510 - f1: 0.8321 - 440ms/step
# Eval samples: 3424
# Epoch 10/10
# step  100/1406 - loss: 0.0000e+00 - precision: 0.8850 - recall: 0.9346 - f1: 0.9091 - 438ms/step
# step  200/1406 - loss: 0.0000e+00 - precision: 0.8802 - recall: 0.9334 - f1: 0.9060 - 471ms/step
# step  300/1406 - loss: 0.0000e+00 - precision: 0.8796 - recall: 0.9346 - f1: 0.9063 - 465ms/step
# step  400/1406 - loss: 0.0000e+00 - precision: 0.8797 - recall: 0.9336 - f1: 0.9059 - 469ms/step
# step  500/1406 - loss: 0.0000e+00 - precision: 0.8802 - recall: 0.9336 - f1: 0.9061 - 465ms/step
# step  600/1406 - loss: 0.0000e+00 - precision: 0.8796 - recall: 0.9337 - f1: 0.9059 - 469ms/step
# step  700/1406 - loss: 0.0000e+00 - precision: 0.8799 - recall: 0.9333 - f1: 0.9058 - 469ms/step
# step  800/1406 - loss: 0.0000e+00 - precision: 0.8784 - recall: 0.9328 - f1: 0.9047 - 465ms/step
# step  900/1406 - loss: 0.0000e+00 - precision: 0.8785 - recall: 0.9325 - f1: 0.9047 - 467ms/step
# step 1000/1406 - loss: 0.0000e+00 - precision: 0.8765 - recall: 0.9319 - f1: 0.9033 - 467ms/step
# step 1100/1406 - loss: 0.0000e+00 - precision: 0.8742 - recall: 0.9306 - f1: 0.9015 - 464ms/step
# step 1200/1406 - loss: 5.9859 - precision: 0.8727 - recall: 0.9302 - f1: 0.9006 - 463ms/step
# step 1300/1406 - loss: 0.0000e+00 - precision: 0.8717 - recall: 0.9303 - f1: 0.9000 - 472ms/step
# step 1400/1406 - loss: 0.0000e+00 - precision: 0.8709 - recall: 0.9301 - f1: 0.8995 - 471ms/step
# step 1406/1406 - loss: 0.0000e+00 - precision: 0.8709 - recall: 0.9301 - f1: 0.8995 - 471ms/step
# save checkpoint at /home/aistudio/results/9
# Eval begin...
# step 100/107 - loss: 0.0000e+00 - precision: 0.8314 - recall: 0.8424 - f1: 0.8369 - 449ms/step
# step 107/107 - loss: 0.0000e+00 - precision: 0.8310 - recall: 0.8433 - f1: 0.8371 - 455ms/step
# Eval samples: 3424
# save checkpoint at /home/aistudio/results/final

# %% [markdown]
# # 恢复模型

# %%
# model=paddle.Model(network)

# %%
# import paddle
# optimizer=paddle.optimizer.Adam(learning_rate=0.001,parameters=model.parameters())
# crf_loss=LinearChainCrfLoss(network.crf)
# chunk_evaluator=ChunkEvaluator(label_list=label_vocab.keys(),suffix=True)

# %%
# model.load('results/final')

# %%
# model.prepare(optimizer,crf_loss,chunk_evaluator)

# %%
model.evaluate(eval_data=test_loader,log_freq=10)
# Out:
# Eval begin...
# step  10/107 - loss: 0.0000e+00 - precision: 0.8016 - recall: 0.8741 - f1: 0.8363 - 469ms/step
# step  20/107 - loss: 0.0000e+00 - precision: 0.8239 - recall: 0.8626 - f1: 0.8428 - 414ms/step
# step  30/107 - loss: 0.0000e+00 - precision: 0.8222 - recall: 0.8229 - f1: 0.8226 - 576ms/step
# step  40/107 - loss: 0.0000e+00 - precision: 0.8240 - recall: 0.8263 - f1: 0.8252 - 529ms/step
# step  50/107 - loss: 0.0000e+00 - precision: 0.8281 - recall: 0.8307 - f1: 0.8294 - 532ms/step
# step  60/107 - loss: 0.0000e+00 - precision: 0.8271 - recall: 0.8342 - f1: 0.8306 - 524ms/step
# step  70/107 - loss: 0.3066 - precision: 0.8253 - recall: 0.8364 - f1: 0.8308 - 503ms/step
# step  80/107 - loss: 0.0000e+00 - precision: 0.8274 - recall: 0.8382 - f1: 0.8328 - 494ms/step
# step  90/107 - loss: 0.0000e+00 - precision: 0.8280 - recall: 0.8394 - f1: 0.8336 - 481ms/step
# step 100/107 - loss: 0.0000e+00 - precision: 0.8292 - recall: 0.8411 - f1: 0.8351 - 468ms/step
# step 107/107 - loss: 0.0000e+00 - precision: 0.8312 - recall: 0.8434 - f1: 0.8373 - 459ms/step
# Eval samples: 3424
# {'loss': [0.0],
#  'precision': 0.8312115335975044,
#  'recall': 0.8434425528274446,
#  'f1': 0.8372823779193206}

# %% [markdown]
# # 预测

# %%
outputs,lens,decodes=model.predict(test_data=test_loader)
# Out:
# Predict begin...
# step 107/107 [==============================] - ETA: 36s - 348ms/ste - ETA: 51s - 502ms/ste - ETA: 42s - 425ms/ste - ETA: 38s - 389ms/ste - ETA: 37s - 382ms/ste - ETA: 35s - 374ms/ste - ETA: 32s - 353ms/ste - ETA: 31s - 350ms/ste - ETA: 29s - 336ms/ste - ETA: 28s - 330ms/ste - ETA: 28s - 334ms/ste - ETA: 26s - 325ms/ste - ETA: 25s - 317ms/ste - ETA: 24s - 315ms/ste - ETA: 24s - 318ms/ste - ETA: 23s - 316ms/ste - ETA: 23s - 320ms/ste - ETA: 23s - 329ms/ste - ETA: 22s - 330ms/ste - ETA: 22s - 329ms/ste - ETA: 21s - 328ms/ste - ETA: 20s - 328ms/ste - ETA: 20s - 335ms/ste - ETA: 19s - 332ms/ste - ETA: 18s - 329ms/ste - ETA: 18s - 329ms/ste - ETA: 17s - 329ms/ste - ETA: 16s - 329ms/ste - ETA: 16s - 331ms/ste - ETA: 15s - 330ms/ste - ETA: 14s - 325ms/ste - ETA: 15s - 356ms/ste - ETA: 14s - 353ms/ste - ETA: 13s - 350ms/ste - ETA: 12s - 348ms/ste - ETA: 12s - 351ms/ste - ETA: 13s - 405ms/ste - ETA: 12s - 405ms/ste - ETA: 11s - 402ms/ste - ETA: 10s - 398ms/ste - ETA: 9s - 399ms/ste - ETA: 9s - 400ms/st - ETA: 8s - 398ms/st - ETA: 7s - 395ms/st - ETA: 6s - 393ms/st - ETA: 5s - 389ms/st - ETA: 5s - 390ms/st - ETA: 4s - 386ms/st - ETA: 3s - 382ms/st - ETA: 2s - 380ms/st - ETA: 1s - 378ms/st - ETA: 1s - 379ms/st - ETA: 0s - 377ms/st - 375ms/step
# Predict samples: 3424

# %%
# print(decodes)
# print(len(decodes))

# %%
def parse_decode(ds,decodes,lens,label_vocab):
    decodes=[x for batch in decodes for x in batch]
    lens=[x for batch in lens for x in batch]
    print(len(decodes),len(lens))
    id_label=dict(zip(label_vocab.values(),label_vocab.keys()))
    outputs=[]
    i=0
    for idx,end in enumerate(lens):
        sent=ds.data[idx]['tokens'][:end]
        tags=[id_label[x] for x in decodes[idx][:end]]
        sent_out=[]
        tags_out=[]
        words=""
        for s,t in zip(sent,tags):
            if t.startswith('B-') or t=="O":
                if len(words):
                    sent_out.append(words)
                tags_out.append(t.split('-')[-1])
                words=s
            else:
                words+=s

        if(len(sent_out)<len(tags_out)):
            sent_out.append(words)

        if len(sent_out)!=len(tags_out):
            print(len(sent_out),len(tags_out))
            continue

        cs=[str((s,t)) for s,t in zip(sent_out,tags_out)]
        ss=''.join(cs) 
        i+=1
        outputs.append(ss) 
    return outputs

# %%
pred=parse_decode(test_ds,decodes,lens,label_vocab)
# Out:
# 3424 3424

# %%
pred[2003]
# Out:
# "('有', 'O')('人', 'O')('总结其过', 'ORG')('程', 'O')('曰', 'O')('：', 'O')('“看', 'LOC')('不', 'O')('惯', 'O')('；', 'O')('边', 'O')('上站', 'LOC')('；', 'O')('试试', 'ORG')('看', 'O')('；死了', 'ORG')('算', 'O')('！', 'O')"
